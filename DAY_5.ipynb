# %% [markdown]
# <a href="https://colab.research.google.com/github/kra-dev007/Data-Analytics-using-Python---Projects/blob/main/DAY_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a = np.array([1,2,3,4,5])
print(np.std(a))
# Out:
# 1.4142135623730951

# %%
import numpy as np
a = np.array([1,2,3,4,5])
print(np.var(a))
# Out:
# 2.0

# %%
import numpy as np
a = np.array([1,2,3,4,5])
print(np.cumsum(a))
# Out:
# [ 1  3  6 10 15]
